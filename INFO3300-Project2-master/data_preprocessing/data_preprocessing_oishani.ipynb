# %% [markdown]
# # Loading Necessary Packages

# %%
import numpy as np
import pandas as pd
import re
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the data

# %%
data_sal = pd.read_csv('intermediate_datasets/salaries_filtered.csv')

# %% [markdown]
# ## Looking at the shape and a sample of the data

# %%
# Dropping unnecessary columns
data_sal.drop(data_sal.columns[[0, 5, 6, 7, 8]], axis = 1, inplace = True)
print("Number of rows: ", data_sal.shape[0])
print("Number of columns: ", data_sal.shape[1])
print("\nFirst 5 rows")
data_sal.head(5)
# Out:
# Number of rows:  100
# Number of columns:  4
#
# First 5 rows
#                              School Name  School Type Starting Median Salary  \
# 0  Massachusetts Institute of Technology  Engineering             $72,200.00
# 1     California Institute of Technology  Engineering             $75,500.00
# 2        Worcester Polytechnic Institute  Engineering             $61,000.00
# 3             Carnegie Mellon University  Engineering             $61,800.00
# 4       Rensselaer Polytechnic Institute  Engineering             $61,100.00
#
#   Mid-Career Median Salary
# 0              $126,000.00
# 1              $123,000.00
# 2              $114,000.00
# 3              $111,000.00
# 4              $110,000.00

# %% [markdown]
# # Combining above data with average SAT scores, location, etc for the same schools

# %% [markdown]
# ## Reading the data

# %%
data_sat = pd.read_csv('intermediate_datasets/university_stats.csv')

# %% [markdown]
# ## Looking at the shape and a sample of the data

# %%
# Dropping unnecessary columns
data_sat.drop(data_sat.columns[[0]], axis = 1, inplace = True)
data_sat.columns = ["School Name", "Average SAT Score", "City", "State", "Latitude", "Longitude"]
print("Number of rows: ", data_sat.shape[0])
print("Number of columns: ", data_sat.shape[1])
print("\nFirst 5 rows")
data_sat.head(5)
# Out:
# Number of rows:  100
# Number of columns:  6
#
# First 5 rows
#                              School Name  Average SAT Score       City State  \
# 0                   Princeton University             1400.0  Princeton    NJ
# 1                     Harvard University             1430.0  Cambridge    MA
# 2                        Yale University             1420.0  New Haven    CT
# 3                    Columbia University             1430.0   New York    NY
# 4  Massachusetts Institute of Technology             1460.0  Cambridge    MA
#
#    Latitude  Longitude
# 0   40.3563   -74.6693
# 1   42.3759   -71.1185
# 2   41.3112   -72.9246
# 3   40.6943   -73.9249
# 4   42.3759   -71.1185

# %% [markdown]
# ## Merging datasets

# %%
merged_ds = data_sal.merge(data_sat, left_on='School Name', right_on='School Name')

# %%
merged_ds.head(10)
# Out:
#                              School Name  School Type Starting Median Salary  \
# 0  Massachusetts Institute of Technology  Engineering             $72,200.00
# 1     California Institute of Technology  Engineering             $75,500.00
# 2        Worcester Polytechnic Institute  Engineering             $61,000.00
# 3             Carnegie Mellon University  Engineering             $61,800.00
# 4       Rensselaer Polytechnic Institute  Engineering             $61,100.00
# 5        Georgia Institute of Technology  Engineering             $58,300.00
# 6               Colorado School of Mines  Engineering             $58,100.00
# 7        Stevens Institute of Technology  Engineering             $60,600.00
# 8       Illinois Institute of Technology  Engineering             $56,000.00
# 9      Rochester Institute of Technology  Engineering             $48,900.00
#
#   Mid-Career Median Salary  Average SAT Score        City State  Latitude  \
# 0              $126,000.00             1460.0   Cambridge    MA   42.3759
# 1              $123,000.00             1510.0    Pasadena    CA   34.1597
# 2              $114,000.00             1200.0   Worcester    MA   42.2705
# 3              $111,000.00             1380.0  Pittsburgh    PA   40.4396
# 4              $110,000.00             1280.0        Troy    NY   42.7354
# 5              $106,000.00             1320.0     Atlanta    GA   33.7627
# 6              $106,000.00             1250.0      Golden    CO   39.7406
# 7              $105,000.00             1260.0     Hoboken    NJ   40.7453
# 8               $97,800.00             1130.0     Chicago    IL   41.8373
# 9               $84,600.00             1140.0   Rochester    NY   43.1680
#
#    Longitude
# 0   -71.1185
# 1  -118.1390
# 2   -71.8079
# 3   -79.9762
# 4   -73.6751
# 5   -84.4224
# 6  -105.2118
# 7   -74.0279
# 8   -87.6862
# 9   -77.6162

# %% [markdown]
# # Combining school region data with the above dataset

# %%
data_reg = pd.read_csv('original_datasets/salaries-by-region.csv')

# %%
# Formatting school names
for i in range(len(data_reg['School Name'])):
    
    # replace abbreviations
    sub = re.sub(r'\s\([^)]*\)', '', data_reg['School Name'][i])
    data_reg['School Name'][i] = sub
    
    # replace comma with - 
    replace_comma = data_reg['School Name'][i].replace(', ', '-')
    data_reg['School Name'][i] = replace_comma
    
    # replace spacing around - 
    if '- ' in data_reg['School Name'][i]:
        replace_spacing_left = data_reg['School Name'][i].replace('- ', '-')
        data_reg['School Name'][i] = replace_spacing_left
        
    elif ' -' in data_reg['School Name'][i]:
        replace_spacing_right = data_reg['School Name'][i].replace(' -', '-')
        data_reg['School Name'][i] = replace_spacing_right

# %%
data_reg.head(5)
# Out:
#                           School Name      Region Starting Median Salary  \
# 0                 Stanford University  California             $70,400.00
# 1  California Institute of Technology  California             $75,500.00
# 2                 Harvey Mudd College  California             $71,800.00
# 3   University of California-Berkeley  California             $59,900.00
# 4                  Occidental College  California             $51,900.00
#
#   Mid-Career Median Salary Mid-Career 10th Percentile Salary  \
# 0              $129,000.00                        $68,400.00
# 1              $123,000.00                               NaN
# 2              $122,000.00                               NaN
# 3              $112,000.00                        $59,500.00
# 4              $105,000.00                               NaN
#
#   Mid-Career 25th Percentile Salary Mid-Career 75th Percentile Salary  \
# 0                        $93,100.00                       $184,000.00
# 1                       $104,000.00                       $161,000.00
# 2                        $96,000.00                       $180,000.00
# 3                        $81,000.00                       $149,000.00
# 4                        $54,800.00                       $157,000.00
#
#   Mid-Career 90th Percentile Salary
# 0                       $257,000.00
# 1                               NaN
# 2                               NaN
# 3                       $201,000.00
# 4                               NaN

# %%
merged_ds_reg = data_reg.merge(merged_ds, left_on='School Name', right_on='School Name')

# %%
merged_ds_reg.drop(merged_ds_reg.columns[[4, 5, 6, 7, 9, 10]], axis = 1, inplace = True)
merged_ds_reg.columns = ["School Name", "Region", "Starting Median Salary", "Mid-Career Median Salary", "School Type", "Average SAT Score", "City", "State", "Latitude", "Longitude"]

# %%
merged_ds_reg
# Out:
#                            School Name        Region Starting Median Salary  \
# 0   California Institute of Technology    California             $75,500.00
# 1    University of California-Berkeley    California             $59,900.00
# 2   University of California-San Diego    California             $51,100.00
# 3       University of California-Davis    California             $52,300.00
# 4      University of California-Irvine    California             $48,300.00
# ..                                 ...           ...                    ...
# 95           University of Connecticut  Northeastern             $48,000.00
# 96          University of Rhode Island  Northeastern             $43,900.00
# 97   Rochester Institute of Technology  Northeastern             $48,900.00
# 98               University of Vermont  Northeastern             $44,800.00
# 99         University of New Hampshire  Northeastern             $41,800.00
#
#    Mid-Career Median Salary  School Type  Average SAT Score        City State  \
# 0               $123,000.00  Engineering             1510.0    Pasadena    CA
# 1               $112,000.00        State             1300.0    Berkeley    CA
# 2               $101,000.00        State             1140.0    La Jolla    CA
# 3                $99,600.00        State             1050.0       Davis    CA
# 4                $96,700.00        State             1060.0      Irvine    CA
# ..                      ...          ...                ...         ...   ...
# 95               $88,800.00        State             1130.0      Storrs    CT
# 96               $85,300.00        State              990.0    Kingston    RI
# 97               $84,600.00  Engineering             1140.0   Rochester    NY
# 98               $82,700.00        State             1100.0  Burlington    VT
# 99               $78,300.00        Party              990.0      Durham    NH
#
#     Latitude  Longitude
# 0    34.1597  -118.1390
# 1    37.8723  -122.2760
# 2    32.8328   117.2713
# 3    38.5552  -121.7365
# 4    33.6772  -117.7738
# ..       ...        ...
# 95   41.8045   -72.2552
# 96   41.4738   -71.5236
# 97   43.1680   -77.6162
# 98   44.4877   -73.2314
# 99   43.1340    70.9264
#
# [100 rows x 10 columns]

# %%
# Converting salaries to float values

for i in range(len(merged_ds_reg['Starting Median Salary'])):
    
    # replace "$" and comma with "" 
    replace_dollar = merged_ds_reg['Starting Median Salary'][i].replace('$', '')
    replace_comma = replace_dollar.replace(',', '')
    merged_ds_reg['Starting Median Salary'][i] = replace_comma
    
for i in range(len(merged_ds_reg['Mid-Career Median Salary'])):
    
    # replace "$" and comma with "" 
    replace_dollar = merged_ds_reg['Mid-Career Median Salary'][i].replace('$', '')
    replace_comma = replace_dollar.replace(',', '')
    merged_ds_reg['Mid-Career Median Salary'][i] = replace_comma

# %%
merged_ds_reg["Starting Median Salary"] = pd.to_numeric(merged_ds_reg["Starting Median Salary"])
merged_ds_reg["Mid-Career Median Salary"] = pd.to_numeric(merged_ds_reg["Mid-Career Median Salary"])

# %%
merged_ds_reg
# Out:
#                            School Name        Region  Starting Median Salary  \
# 0   California Institute of Technology    California                 75500.0
# 1    University of California-Berkeley    California                 59900.0
# 2   University of California-San Diego    California                 51100.0
# 3       University of California-Davis    California                 52300.0
# 4      University of California-Irvine    California                 48300.0
# ..                                 ...           ...                     ...
# 95           University of Connecticut  Northeastern                 48000.0
# 96          University of Rhode Island  Northeastern                 43900.0
# 97   Rochester Institute of Technology  Northeastern                 48900.0
# 98               University of Vermont  Northeastern                 44800.0
# 99         University of New Hampshire  Northeastern                 41800.0
#
#     Mid-Career Median Salary  School Type  Average SAT Score        City  \
# 0                   123000.0  Engineering             1510.0    Pasadena
# 1                   112000.0        State             1300.0    Berkeley
# 2                   101000.0        State             1140.0    La Jolla
# 3                    99600.0        State             1050.0       Davis
# 4                    96700.0        State             1060.0      Irvine
# ..                       ...          ...                ...         ...
# 95                   88800.0        State             1130.0      Storrs
# 96                   85300.0        State              990.0    Kingston
# 97                   84600.0  Engineering             1140.0   Rochester
# 98                   82700.0        State             1100.0  Burlington
# 99                   78300.0        Party              990.0      Durham
#
#    State  Latitude  Longitude
# 0     CA   34.1597  -118.1390
# 1     CA   37.8723  -122.2760
# 2     CA   32.8328   117.2713
# 3     CA   38.5552  -121.7365
# 4     CA   33.6772  -117.7738
# ..   ...       ...        ...
# 95    CT   41.8045   -72.2552
# 96    RI   41.4738   -71.5236
# 97    NY   43.1680   -77.6162
# 98    VT   44.4877   -73.2314
# 99    NH   43.1340    70.9264
#
# [100 rows x 10 columns]

# %% [markdown]
# # Exporting as one of the final datasets to be used

# %%
merged_ds_reg.to_csv('region_sat_school.csv', index = False)

# %% [markdown]
# # Exploring the new csv file

# %%
ds1 = pd.read_csv('region_sat_school.csv')

# %%
data_struct = pd.DataFrame(data = ds1.columns, columns = ['columns']) # columns
data_struct['unique_values'] = ds1.nunique().values # number of unique values
data_struct['dtype'] = ds1.dtypes.values # data types
data_struct['nulls'] = ds1.isnull().sum().values # number of null or missing values

# %%
data_struct
# Out:
#                     columns  unique_values    dtype  nulls
# 0               School Name            100   object      0
# 1                    Region              5   object      0
# 2    Starting Median Salary             76  float64      0
# 3  Mid-Career Median Salary             81  float64      0
# 4               School Type              4   object      0
# 5         Average SAT Score             48  float64      5
# 6                      City             97   object      0
# 7                     State             42   object      0
# 8                  Latitude             98  float64      0
# 9                 Longitude             98  float64      0

# %% [markdown]
# # Cleaning dataset of salaries by major

# %% [markdown]
# ## Reading the data

# %%
data_major = pd.read_csv('original_datasets/degrees-that-pay-back.csv')

# %% [markdown]
# ## Looking at the shape and sample of the data

# %%
# Dropping unnecessary columns
data_major.drop(data_major.columns[[4, 5, 6, 7]], axis = 1, inplace = True)
print("Number of rows: ", data_major.shape[0])
print("Number of columns: ", data_major.shape[1])
print("\nFirst 5 rows")
data_major.head(5)
# Out:
# Number of rows:  50
# Number of columns:  4
#
# First 5 rows
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6

# %%
# Converting salaries to float values

for i in range(len(data_major['Starting Median Salary'])):
    
    # replace "$" and comma with "" 
    replace_dollar = data_major['Starting Median Salary'][i].replace('$', '')
    replace_comma = replace_dollar.replace(',', '')
    data_major['Starting Median Salary'][i] = replace_comma
    
for i in range(len(data_major['Mid-Career Median Salary'])):
    
    # replace "$" and comma with "" 
    replace_dollar = data_major['Mid-Career Median Salary'][i].replace('$', '')
    replace_comma = replace_dollar.replace(',', '')
    data_major['Mid-Career Median Salary'][i] = replace_comma

# %%
data_major["Starting Median Salary"] = pd.to_numeric(data_major["Starting Median Salary"])
data_major["Mid-Career Median Salary"] = pd.to_numeric(data_major["Mid-Career Median Salary"])

# %%
data_major.head(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Percent change from Starting to Mid-Career Salary
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6

# %%
data_struct1 = pd.DataFrame(data = data_major.columns, columns = ['columns']) # columns
data_struct1['unique_values'] = data_major.nunique().values # number of unique values
data_struct1['dtype'] = data_major.dtypes.values # data types
data_struct1['nulls'] = data_major.isnull().sum().values # number of null or missing values

# %%
data_struct1
# Out:
#                                              columns  unique_values    dtype  \
# 0                                Undergraduate Major             50   object
# 1                             Starting Median Salary             43  float64
# 2                           Mid-Career Median Salary             49  float64
# 3  Percent change from Starting to Mid-Career Salary             48  float64
#
#    nulls
# 0      0
# 1      0
# 2      0
# 3      0

# %% [markdown]
# # Exporting as one of the final datasets to be used

# %%
data_major.to_csv('major_salaries.csv', index = False)

# %% [markdown]
# # Exploring the new csv file

# %%
ds2 = pd.read_csv('major_salaries.csv')

# %%
data_struct2 = pd.DataFrame(data = ds2.columns, columns = ['columns']) # columns
data_struct2['unique_values'] = ds2.nunique().values # number of unique values
data_struct2['dtype'] = ds2.dtypes.values # data types
data_struct2['nulls'] = ds2.isnull().sum().values # number of null or missing values

# %%
data_struct2
# Out:
#                                              columns  unique_values    dtype  \
# 0                                Undergraduate Major             50   object
# 1                             Starting Median Salary             43  float64
# 2                           Mid-Career Median Salary             49  float64
# 3  Percent change from Starting to Mid-Career Salary             48  float64
#
#    nulls
# 0      0
# 1      0
# 2      0
# 3      0
